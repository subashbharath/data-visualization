# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
tips=sns.load_dataset("tips")
tips
# Out:
# C:\Users\AB\Anaconda3\lib\site-packages\statsmodels\tools\_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
#simple box plot with one axis (xaxis)
'''parameters
x= xaxis colunmname
y= yaxis colunm name
data=dataset object
hue=interpolartion
palatte=colors of each image
color=all in same color
order= order of xaxis
linewidth=width of line
orient=h_ horitonal'''
sns.boxplot(x=tips["total_bill"])
plt.title("boxplot")
plt.show()

# %%
#simple boxplot with two axis
sns.boxplot(x="sex",y="total_bill",data=tips)
plt.title("boxplot")
plt.show()

# %%
#with hue
sns.boxplot(x="sex",y="total_bill",data=tips,hue="smoker")
plt.title("boxplot")
plt.show()

# %%
#with hue and with palette=
sns.boxplot(x="sex",y="total_bill",data=tips,hue="smoker",palette="prism")
plt.title("boxplot")
plt.show()

# %%
#linewidth
sns.boxplot(x="day", y="total_bill", hue="time",data=tips, linewidth=2.5)

# %%
#order
sns.boxplot(x="time", y="tip", data=tips,order=["Dinner", "Lunch"])

# %%
#orientation
iris = sns.load_dataset("iris")
sns.boxplot(data=iris, orient="h", palette="Set2")

# %%
#orientation
iris = sns.load_dataset("iris")
sns.boxplot(data=iris, orient="v", palette="Set2")
sns.swarmplot(data=iris)

# %%
sns.swarmplot(data=iris)
